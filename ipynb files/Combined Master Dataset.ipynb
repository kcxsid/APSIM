# %%
import numpy as np 
import pandas as pd 
import os

import seaborn as sns 
import matplotlib.pyplot as plt 
import csv

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
master = pd.read_csv('C:\\Users\\siddh\\Desktop\\DES\\Datasets For Use\\master_combined.csv')
master.head()
# Out:
# C:\Users\siddh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (9,10,13,14,20,21,22,23,24,25,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DataStore        Dataset       Provider    Location_ID  Layer_ID  SampleID  \
# 0      SALI  QLDGovernment  QLDGovernment  QLD_3MC_153_1       2.0       2.0
# 1      SALI  QLDGovernment  QLDGovernment  QLD_3MC_153_1       4.0       4.0
# 2      SALI  QLDGovernment  QLDGovernment  QLD_3MC_153_1       5.0       5.0
# 3      SALI  QLDGovernment  QLDGovernment  QLD_3MC_153_1       8.0       8.0
# 4      SALI  QLDGovernment  QLDGovernment  QLD_3MC_153_1      11.0      11.0
#
#    SampleDate   Longitude  Latitude UpperDepth  ... QualSpatialAccuracy  \
# 0  01-01-1993  151.160172 -24.85381          0  ...                 3.0
# 1  01-01-1993  151.160172 -24.85381       0.15  ...                 3.0
# ...

# %%
# Splitting the master dataset into various sources, for analysis on a source-based scale.

# This is done so that the information provided by each source, is entirely consistent 
# within the dataframe of that particular source. 
providers = master['Provider'].unique()
len(providers)

for i in providers: 
    df = master[master['Provider']==i]
    path = 'C:\\Users\\siddh\\Desktop\\DES\\Provider Split Datasets\\'
    filename = i+'.csv'
    df.to_csv(path+filename)

# %%
master['UNITS'].isnull().sum()
# Out:
# 519572

# %%
master['UpperDepth'] = pd.to_numeric(master.UpperDepth, errors = 'coerce')

# %%
master['LowerDepth'] = pd.to_numeric(master.LowerDepth, errors = 'coerce')

# %%
master
# Out:
#         DataStore        Dataset       Provider     Location_ID  Layer_ID  \
# 0            SALI  QLDGovernment  QLDGovernment   QLD_3MC_153_1       2.0
# 1            SALI  QLDGovernment  QLDGovernment   QLD_3MC_153_1       4.0
# 2            SALI  QLDGovernment  QLDGovernment   QLD_3MC_153_1       5.0
# 3            SALI  QLDGovernment  QLDGovernment   QLD_3MC_153_1       8.0
# 4            SALI  QLDGovernment  QLDGovernment   QLD_3MC_153_1      11.0
# ...           ...            ...            ...             ...       ...
# 2039867     ASRIS        NatSoil          CSIRO  899_SSM_SSM9_1       1.0
# 2039868     ASRIS        NatSoil          CSIRO  899_SSM_SSM9_1       2.0
# 2039869     ASRIS        NatSoil          CSIRO  899_SSM_SSM9_1       3.0
# 2039870     ASRIS        NatSoil          CSIRO  899_SSM_SSM9_1       4.0
# 2039871     ASRIS        NatSoil          CSIRO  899_SSM_SSM9_1       6.0
#
#          SampleID  SampleDate   Longitude  Latitude  UpperDepth  ...  \
# ...

# %%
directory = 'C:\\Users\\siddh\\Desktop\\DES\\Provider Split Datasets\\'
files = os.listdir(directory)
files
# Out:
# ['CSIRO.csv',
#  'GA.csv',
#  'NTGovernment.csv',
#  'QLDGovernment.csv',
#  'SAGovernment.csv',
#  'SAParksAndWildlife.csv',
#  'TasGovernment.csv',
#  'TERN.csv',
#  'WAGovernment.csv',
#  'WAParksAndWildlife.csv']

# %%
method_names = master['ObservedProperty'].unique()

# %%
len(method_names)
# Out:
# 374

# %%
#methods that have the most occurrences in the master dataset. 

#Instead of finding the correlation of all methods, just find the correlation of the top 30 methods 
#in the dataset. 




method_occurrences = pd.value_counts(master['LAB_METH_CODE'])



t1 = pd.value_counts(master['ObservedProperty'])
len(t1), len(method_occurrences)
# Out:
# (374, 187)

# %%
# For each file (as per the providers of data), generate smaller dataframes of each method and store it under the 
# parent file name. 
len(method_occurrences)
# Out:
# 187

# %%
directory = 'C:\\Users\\siddh\\Desktop\\DES\\ObservedProperties\\'
file_names = os.listdir(directory)
file_names
# Out:
# []

# %%
obs_prop = (master['ObservedProperty'].unique())
len(obs_prop)
# Out:
# 374

# %%
for i in obs_prop: 
    
    obsprop_df = master.loc[master['ObservedProperty'] == i]
    file_name = i+'.csv'
    obsprop_df.to_csv(directory+file_name)

# %%
# Top 30 methods in the master dataframe, which has the highest number of occurrences. 
directory1 = 'C:\\Users\\siddh\\Desktop\\DES\\HighlyOccuringObservedProperties\\'

lt = list(method_occurrences.index)

for j in lt: 
    temp_df = master.loc[master['ObservedProperty'] == j]
    file_name = j+'.csv'
    obsprop_df.to_csv(directory1+file_name)

# %%
for i in method_occurrences.index[0:30]:
    print(i)

# %%
#master.loc[master['ObservedProperty'] == method_occurrences.index[0]]

# %%
lt = list(method_occurrences.index[0:30])

# %%
lt
# Out:
# ['3A1',
#  '5A2',
#  '2A1',
#  '7B1',
#  '6A1',
#  '10A1',
#  '9A1',
#  '17A1',
#  'P10_NR_C',
#  'P10_NR_Z',
#  '15_NR_K',
#  '2Z2_FS',
#  '2Z2_CS',
#  '3_NR',
#  '2Z2_Clay',
#  '2Z2_Silt',
#  '7A2',
#  '15C1_K',
#  '9B2',
#  '20Be',
#  '15C1_CEC',
#  '15A1_K',
#  '5_NR',
#  '15N1',
#  '18A1',
#  'P10_NR_CS',
#  'P10_NR_FS',
#  '22B',
#  '2_LOI',
#  '12C1']

# %%
master['DataStore'].unique()
# Out:
# array(['SALI', 'ASRIS', 'SAsqlLite', 'ASRISSQLTas', 'TERNLandscapesDB',
#        'TERNSurveillance'], dtype=object)

# %%
len(master['ObservedProperty'].unique())
# Out:
# 374

# %%
value = master['Latitude'].isnull().sum()

value2 = master['Longitude'].isnull().sum()

value, value2
# Out:
# (102756, 102756)

# %%
nulldf = master[master['Latitude'].isnull()]
master.drop(nulldf)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-87f75c9ab1c1> in <module>
#       1 nulldf = master[master['Latitude'].isnull()]
# ----> 2 master.drop(nulldf)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
temp_df = master.drop(master[master['Latitude'].isnull()].index, inplace = False)

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1937116 entries, 0 to 2039871
# Data columns (total 28 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   DataStore               object
#  1   Dataset                 object
#  2   Provider                object
#  3   Location_ID             object
#  4   Layer_ID                float64
#  5   SampleID                float64
#  6   SampleDate              object
#  7   Longitude               float64
#  8   Latitude                float64
#  9   UpperDepth              float64
#  10  LowerDepth              float64
#  11  PropertyType            object
#  12  ObservedProperty        object
#  13  Value                   object
#  14  Units                   object
#  15  QualCollection          float64
#  16  QualSpatialAggregation  float64
#  17  QualManagement          float64
#  18  QualSpatialAccuracy     float64
#  19  ExtractTime             object
# ...

# %%
temp_df
# Out:
#         DataStore        Dataset       Provider     Location_ID  Layer_ID  \
# 0            SALI  QLDGovernment  QLDGovernment   QLD_3MC_153_1       2.0
# 1            SALI  QLDGovernment  QLDGovernment   QLD_3MC_153_1       4.0
# 2            SALI  QLDGovernment  QLDGovernment   QLD_3MC_153_1       5.0
# 3            SALI  QLDGovernment  QLDGovernment   QLD_3MC_153_1       8.0
# 4            SALI  QLDGovernment  QLDGovernment   QLD_3MC_153_1      11.0
# ...           ...            ...            ...             ...       ...
# 2039867     ASRIS        NatSoil          CSIRO  899_SSM_SSM9_1       1.0
# 2039868     ASRIS        NatSoil          CSIRO  899_SSM_SSM9_1       2.0
# 2039869     ASRIS        NatSoil          CSIRO  899_SSM_SSM9_1       3.0
# 2039870     ASRIS        NatSoil          CSIRO  899_SSM_SSM9_1       4.0
# 2039871     ASRIS        NatSoil          CSIRO  899_SSM_SSM9_1       6.0
#
#          SampleID  SampleDate   Longitude  Latitude  UpperDepth  ...  \
# ...
